# %%
from pprint import pprint
import json

import azure.cosmos.cosmos_client as cosmos_client
import azure.cosmos.documents as documents
import azure.cosmos.errors as errors

# %%
COSMOSDB_ENDPOINT = '{AZURE_COSMOS_DB_ENDPOINT}'
COSMOSDB_PRIMARY_KEY = '{AZURE_COSMOS_DB_PRIMARY_KEY}'
COSMOSDB_DB_ID = 'UniversityDatabase'
COSMOSDB_COLL_ID = 'StudentCollection'

client = cosmos_client.CosmosClient(COSMOSDB_ENDPOINT, { 'masterKey': COSMOSDB_PRIMARY_KEY })
database_link = f'dbs/{COSMOSDB_DB_ID}'
throughput = 11000
partition_key = '/enrollmentYear'
unique_key = '/studentAlias'
collection_link = f'{database_link}/colls/{COSMOSDB_COLL_ID}'

# %%
def create_database(id):
    print('Create database')

    try:
        client.CreateDatabase({"id": id})
        print(f'Database with id "{id}" created')

    except errors.HTTPFailure as e:
        if e.status_code == 409:
           print(f'A database with id "{id}" already exists')
        else: 
            raise

# %%
create_database(COSMOSDB_DB_ID)
# Out:
# Create database
# Database with id "UniversityDatabase" created

# %%
def create_container(id, throughput, partition_key, unique_key):
    try:
        coll = {
            "id": id,
            "partitionKey": {
                "paths": [
                    partition_key
                ],
                "kind": "Hash",
                "version": 2
            },
            'uniqueKeyPolicy': {
                'uniqueKeys': [
                    { 'paths': [ unique_key ] }
                ]
            }
        }
        collection_options = { 'offerThroughput': throughput }
        collection = client.CreateContainer(database_link, coll, collection_options)

        print(f'Collection with id "{id}" created')
        print(f'Partition Key - "{partition_key}"')

    except errors.CosmosError as e:
        if e.status_code == 409:
            print(f'A collection with id "{id}" already exists')
        else:
            raise

# %%
create_container(COSMOSDB_COLL_ID, throughput, partition_key, unique_key)
# Out:
# Collection with id "StudentCollection" created
# Partition Key - "/enrollmentYear"

# %%
def create_documents(docs):
    client.CreateItem(collection_link, docs)

# %%
# The upload may take up to 15 minutes to complete

with open('../data/students-25%.json') as json_file:
    students_json = json.load(json_file)
    for student in students_json:
        create_documents(student)

# %%
def query_documents(collection_link, query, options={ "enableCrossPartitionQuery": True }):
    try:
        results = list(client.QueryItems(collection_link, query, options))
        return results

    except errors.HTTPFailure as e:
        if e.status_code == 404:
            print("Document doesn't exist")
        elif e.status_code == 400:
            # Can occur when we are trying to query on excluded paths
            print("Bad Request exception occured: ", e)
            pass
        else:
            raise

    finally:
        print()

# %%
query = 'SELECT * FROM students s WHERE s.enrollmentYear = 2017'
query_results = query_documents(collection_link, query)

print(f'Length of query results: {len(query_results)}')
pprint(query_results[0])
# Out:
# Length of query results: 2111
# {'_attachments': 'attachments/',
#  '_etag': '"07006432-0000-0100-0000-5e34673e0000"',
#  '_rid': 'optQAMq6M+ACAAAAAAAACA==',
#  '_self': 'dbs/optQAA==/colls/optQAMq6M+A=/docs/optQAMq6M+ACAAAAAAAACA==/',
#  '_ts': 1580492606,
#  'academicStatus': {'expulsion': False, 'suspension': False, 'warning': False},
#  'age': 20,
#  'clubs': ['MMA Club'],
#  'enrollmentYear': 2017,
#  'financialData': {'tuitionBalance': 0,
#                    'tuitionPayments': [{'amount': 3200, 'date': '2017-01-13'},
#                                        {'amount': 3400, 'date': '2016-07-08'},
#                                        {'amount': 4000, 'date': '2017-03-18'},
#                                        {'amount': 4000, 'date': '2017-09-22'},
#                                        {'amount': 2900, 'date': '2017-09-01'}],
#                    'unusedFinancialAid': 0},
#  'firstName': 'Albin',
#  'homeAddress': {'city': 'Jaedenhaven',
#                  'numberAndStreet': '8352 Garfield Neck',
#                  'postalCode': '22643',
#                  'stateProvince': 'Nevada'},
#  'homeEmailAddress': 'Albin_VonRueden@gmail.com',
#  'id': 'da814879-ef58-4805-bc2b-9c4bb5dc1a3e',
#  'isActivelyEnrolled': True,
#  'lastName': 'VonRueden',
#  'projectedGraduationYear': 2024,
#  'studentAlias': 'albinvonrueden168071'}

# %%
# In this query, we drop the 's' alias and use the 'students' source. When we execute this query, we should see the same results as the previous query.

query = 'SELECT * FROM students WHERE students.enrollmentYear = 2017'
query_results = query_documents(collection_link, query)

print(f'Length of query results: {len(query_results)}')
# Out:
# Length of query results: 2111

# %%
# In this query, we will prove that the name used for the source can be any name you choose. We will use the name 'arbitraryname' for the source.
# When we execute this query, we should see the same results as the previous query.

query = 'SELECT * FROM arbitraryname WHERE arbitraryname.enrollmentYear = 2017'
query_results = query_documents(collection_link, query)

print(f'Length of query results: {len(query_results)}')
# Out:
# Length of query results: 2111

# %%
# Going back to 's' as an alias, we will now create a query where we only select the 'studentAlias' property and return the value of
# that property in our result set.

query = 'SELECT s.studentAlias FROM students s WHERE s.enrollmentYear = 2017'
query_results = query_documents(collection_link, query)

print(f'Length of query results: {len(query_results)}')
pprint(query_results[0])
# Out:
# Length of query results: 2111
# {'studentAlias': 'albinvonrueden168071'}

# %%
# In some scenarios, you may need to return a flattened array as the result of your query. This query uses the 'VALUE' keyword to flatten
# the array by taking the single returned (string) property and creating a string array.

query = 'SELECT VALUE s.studentAlias FROM students s WHERE s.enrollmentYear = 2017'
query_results = query_documents(collection_link, query)

print(f'Length of query results: {len(query_results)}')
pprint(query_results)
# Out:
# Length of query results: 2111
# ['albinvonrueden168071',
#  'caliabbott079142',
#  'maeterry067504',
#  'mathildehartmann036171',
#  'remingtondaugherty069221',
#  'kennethtreutel003169',
#  'angelrogahn065095',
#  'yesseniathiel051729',
#  'wilfredorosenbaum164029',
#  'norbertojacobs016273',
#  'olliethiel025164',
#  'alvinagraham084904',
#  'bennettsporer069310',
#  'lessiedietrich096075',
#  'elnaherzog170956',
#  'elizabethshields151582',
#  'nayelifranecki035212',
#  'dameonpredovic105822',
#  'beauframi066057',
#  'dorthajakubowski138384',
#  'maudiekertzmann025704',
#  'annettakris072416',
#  'janickweber104027',
#  'tamiabins018592',
#  'estelltrantow026638',
#  'rogerkoss059505',
#  'myronbartoletti022668',
#  'kennedyhermann129585',
#  'aldarath147774',
#  'burleywunsch091282',
#  'anyakihn156771',
#  'ottiliejacobs015175',
#  'marvingrady016483',
#  'audreannewindler035930',
#  'hopebogan141891',
#  'lucilebrakus168276',
#  'luellajacobs000373',
#  'verliehayes144686',
#  'jonasbogan076224',
#  'mariamkreiger038801',
#  'kolenitzsche092376',
#  'lavernlangworth092193',
#  'steverutherford118104',
#  'antoniopurdy070331',
#  'chancemayert054526',
#  'kathrynelittel159781',
#  'gailheidenreich047994',
#  'danykaspinka079346',
#  'madelynwyman052377',
#  'trevergreenfelder119611',
#  'cassiedeckow146057',
#  'elmoconnelly061020',
#  'reillyeffertz095223',
#  'mohammedfriesen061223',
#  'janniewolf027225',
#  'lennagoyette081247',
#  'heleneruecker139631',
#  'luciuskoepp174657',
#  'vernabauch080308',
#  'bettyewilderman022084',
#  'lorenzfadel159415',
#  'jonaswilkinson057665',
#  'murrayaltenwerth018799',
#  'leliakrajcik026867',
#  'retajacobi004801',
#  'pamelashanahan057532',
#  'bricefisher020134',
#  'durwardmorar162296',
#  'jaidenschuppe053389',
#  'jaceydaniel167797',
#  'maymieprosacco155063',
#  'brennacarroll027958',
#  'luigioconner087327',
#  'silaswiegand004799',
#  'ignaciorogahn004964',
#  'anaisrowe068748',
#  'mylenehoppe149479',
#  'henriprosacco134002',
#  'domenickbahringer042697',
#  'deonmarvin153327',
#  'roslynhintz016673',
#  'loniekozey102641',
#  'orphagutkowski002132',
#  'adahkirlin076641',
#  'lucienneborer108717',
#  'assuntasanford054439',
#  'cleostreich033124',
#  'herbertcorkery124598',
#  'hattiekihn067281',
#  'tessspinka120910',
#  'juanadooley167402',
#  'loyalgerlach172278',
#  'zackarystreich026081',
#  'modestoschneider039965',
#  'einarbechtelar060881',
#  'maymiewilliamson130901',
#  'heidimcglynn107364',
#  'madonnarutherford091204',
#  'waldozieme037627',
#  'merlinbalistreri140298',
#  'ryanndeckow026796',
#  'bertakris100873',
#  'alejandrinschamberger139172',
#  'blancheullrich051932',
#  'abdullahmcclure143290',
#  'rowenajones042714',
#  'nicoemard147847',
#  'shaynevon072822',
#  'margueritelegros133877',
#  'meggiemorar029028',
#  'rowenasenger149054',
#  'estevankohler041906',
#  'andycarroll011414',
#  'alekgoldner132942',
#  'lisettemedhurst070533',
#  'winnifredcremin021364',
#  'dulcepurdy030701',
#  'jarvislarson099947',
#  'emiliosteuber166873',
#  'mayralehner132497',
#  'eloisahirthe037349',
#  'tierramitchell044681',
#  'ethelynmertz016227',
#  'sibyljast092675',
#  'dorothyschuppe122612',
#  'adelinebahringer086313',
#  'rachelleconroy128984',
#  'christybarrows104858',
#  'waltergislason166362',
#  'richmondlesch076995',
#  'carlosmoore115021',
#  'marquisklocko031021',
#  'matteokshlerin096838',
#  'nasirhintz093516',
#  'arnorempel013564',
#  'mortimerlang018342',
#  'jazmynekulas106481',
#  'laurianejerde157950',
#  'bartonlarson080075',
#  'adriannarath049745',
#  'reinakohler116052',
#  'lukaslarson006929',
#  'daishalehner123272',
#  'maximilliacrist025728',
#  'marjolainereinger088238',
#  'kristyreichel039221',
#  'uriahpfeffer020253',
#  'ezekieldickinson019258',
#  'noblebergnaum028355',
#  'feliperobel064652',
#  'jordynweber038497',
#  'woodrowbartell109347',
#  'chancehaley051160',
#  'danikakonopelski088637',
#  'mortonkozey019011',
#  'etheladams039244',
#  'pietrocasper112160',
#  'lisawest143252',
#  'eldridgelangosh097016',
#  'miraclemedhurst171527',
#  'nigelmarquardt095040',
#  'mariobotsford033774',
#  'saraiortiz000110',
#  'darrellosinski113493',
#  'stantonkoelpin097474',
#  'nicholausdurgan131533',
#  'dantepurdy058805',
#  'curtwalter088139',
#  'bradfordzulauf017336',
#  'susannareinger097026',
#  'adaherzog074628',
#  'daytonjaskolski089107',
#  'mabellelabadie006166',
#  'brucekoch106573',
#  'jedediahdicki004551',
#  'nikitarunte002147',
#  'chloeziemann167447',
#  'ottismertz132397',
#  'elisabethrunolfsson013582',
#  'ashleighherzog038665',
#  'terrygerhold015954',
#  'reydibbert103448',
#  'janmueller096523',
#  'ashtonschaefer121909',
#  'damondoyle044111',
#  'rozellahermann083091',
#  'bradleymohr016599',
#  'angelhilll077668',
#  'kolbystanton056650',
#  'carriewilderman172591',
#  'declanbogan107673',
#  'rickhartmann061811',
#  'elenagreenfelder028522',
#  'malikanikolaus125669',
#  'fionahahn145793',
#  'dorothydietrich075919',
#  'ayanabogan133993',
#  'gregoriomcglynn076347',
#  'ansleymedhurst095845',
#  'oceanemorar067125',
#  'alfonzodurgan000459',
#  'clairleuschke095097',
#  'bethelgusikowski129545',
#  'dawnwolf011125',
#  'lelacasper102205',
#  'ednastrosin155832',
#  'anissablanda115314',
#  'violetokon169207',
#  'diondibbert174918',
#  'carolinaaufderhar048038',
#  'caterinawintheiser062201',
#  'ariannasatterfield050652',
#  'gennaroconn118265',
#  'dixieschroeder129498',
#  'sigmundshanahan039814',
#  'lindseymarquardt058260',
#  'henrycremin038981',
#  'traceybradtke107524',
#  'dominicokuneva169546',
#  'amirgaylord060510',
#  'velmacorkery122738',
#  'ashleighhintz006853',
#  'jaylanhaley167509',
#  'melisaruecker112749',
#  'bettyeparisian141005',
#  'hildaklocko040979',
#  'hollybuckridge163982',
#  'bethelmcdermott035831',
#  'osbaldobradtke029481',
#  'alizeprohaska096147',
#  'beaulahmarvin127169',
#  'eladiodaniel087652',
#  'kathlyngrady019966',
#  'abigaylegrady157349',
#  'ariellezulauf050979',
#  'greysonpfannerstill130815',
#  'rexmertz149156',
#  'genesipes168956',
#  'kiracassin024784',
#  'shaunaufderhar094522',
#  'stephendare154317',
#  'greysonbosco145849',
#  'urbanbrakus034826',
#  'goldaschaefer027209',
#  'delphiakuvalis160194',
#  'lanebalistreri063102',
#  'janessabechtelar148126',
#  'miracleupton169054',
#  'athenalegros115447',
#  'zettaklein127666',
#  'tayabatz052663',
#  'nicholewalker074551',
#  'meaghankautzer071341',
#  'frederiklueilwitz108150',
#  'erichhermann010450',
#  'alvenaskiles146665',
#  'saigeschumm053990',
#  'garretrolfson022783',
#  'marleystanton096785',
#  'ariannapouros138495',
#  'alejandrawiza158726',
#  'margiegibson095972',
#  'trentoneichmann071796',
#  'othaerdman014315',
#  'zelmasporer095214',
#  'leifjones068297',
#  'leoradibbert005693',
#  'brycenokuneva116818',
#  'kurtisdickens020085',
#  'clementinagutkowski116135',
#  'claudwisoky113246',
#  'arnokautzer072856',
#  'darwinwisoky006889',
#  'keshawnernser073913',
#  'royalbeer052078',
#  'jacquelynrath166157',
#  'ferminprice097874',
#  'emmanuellerunte052735',
#  'henrigutkowski125722',
#  'elenoradaniel056788',
#  'antoinetteblanda072771',
#  'avaoconner127425',
#  'barrettwill109634',
#  'clarkbarton164403',
#  'modestamorissette037514',
#  'columbusdach047727',
#  'kristianyost125764',
#  'fannykuphal066706',
#  'tedkoss146449',
#  'alenabotsford011344',
#  'adolphmaggio006809',
#  'adeliabrekke081130',
#  'rollinkovacek011998',
#  'mayewilkinson020195',
#  'randijones105815',
#  'constancekautzer029397',
#  'jeradschmitt152802',
#  'dejontillman023882',
#  'tyreekcole037051',
#  'edmundwindler083683',
#  'daynachamplin044909',
#  'hillarykirlin066129',
#  'budjones107020',
#  'janiedavis038952',
#  'nyasiarodriguez047104',
#  'helgabins107090',
#  'kirstenokeefe165518',
#  'lucileconroy173760',
#  'kaceyframi129277',
#  'laurianebaumbach169356',
#  'stephanienolan131117',
#  'vidalschumm061704',
#  'queenieblanda078054',
#  'orphavolkman137601',
#  'hoytlittle086555',
#  'jimmycartwright129437',
#  'caitlynbeatty024168',
#  'tianadenesik036798',
#  'vedaharris032300',
#  'courtneybuckridge169847',
#  'jaylenmcclure012712',
#  'oswaldotorphy108316',
#  'johnpaulhegmann000948',
#  'calistamonahan013523',
#  'vernonkeeling092181',
#  'franzlabadie069341',
#  'janieglover036218',
#  'lemueljohnston146219',
#  'isaiaspouros135108',
#  'mozellsipes067055',
#  'tomcummerata055965',
#  'kylawisoky062909',
#  'marlonhudson153528',
#  'ransomlittle127305',
#  'jaycegreen155394',
#  'brentbeer157631',
#  'fredafadel107615',
#  'melvinmcdermott040437',
#  'elianequigley052125',
#  'leslieward097455',
#  'monteschiller100453',
#  'baronstark130989',
#  'neldabartoletti150593',
#  'mistyoconnell010385',
#  'amosschaden165728',
#  'mandymaggio147946',
#  'sebastianjones025552',
#  'rafaelakassulke169376',
#  'dustytrantow137045',
#  'chrisupton021856',
#  'leonardofadel007125',
#  'duanemckenzie112166',
#  'amymarks151519',
#  'maxiebeatty081063',
#  'maeheaney145966',
#  'ellagottlieb018271',
#  'mertiemann019586',
#  'laynegislason025892',
#  'kyleesawayn131878',
#  'creolasauer170175',
#  'lonnylind172533',
#  'alvawindler133526',
#  'kamronsanford170635',
#  'lillianohara171684',
#  'feltonluettgen098289',
#  'emanuelschiller069565',
#  'noemiefay031562',
#  'ocieprohaska150437',
#  'franzmonahan117933',
#  'rosettaharvey133683',
#  'leslyjacobson076059',
#  'curtisgrimes014432',
#  'adamlowe090162',
#  'keeganmiller057858',
#  'aileenleannon047750',
#  'connerhickle059167',
#  'jazlynokuneva144671',
#  'claudiakuvalis051299',
#  'calistathiel100325',
#  'turnerhammes003263',
#  'cleorawhite150305',
#  'billiestamm003249',
#  'rosemariesatterfield017617',
#  'danamraz042076',
#  'keegancremin020639',
#  'yoshikonikolaus121873',
#  'shaunbosco035390',
#  'rosalindaschultz002950',
#  'ludiearmstrong090508',
#  'jazmynebarton017722',
#  'jodyyundt072949',
#  'auroretoy114260',
#  'rosiebeer009376',
#  'gustebert153693',
#  'carrieconroy056972',
#  'theresarohan171411',
#  'albertmiller145075',
#  'georgianatorphy062447',
#  'dessiebailey131954',
#  'delmerbreitenberg136357',
#  'kaelynlangosh006459',
#  'wandaanderson162638',
#  'devonpurdy036581',
#  'justinamueller059162',
#  'nayeliemmerich125478',
#  'janicegerhold079627',
#  'bettyebashirian018940',
#  'ednabrown052834',
#  'nedrahilpert131801',
#  'orierenner165481',
#  'mosepouros005513',
#  'tillmanrippin036922',
#  'vernergoldner002489',
#  'romakuvalis168986',
#  'tabitharenner085151',
#  'willflatley103086',
#  'jaysonweber115757',
#  'edisonhahn041754',
#  'rosenolan007109',
#  'gildakulas067928',
#  'everetteskiles061820',
#  'alphonsotromp078534',
#  'kayleestoltenberg077624',
#  'rayhodkiewicz144746',
#  'russellhintz003634',
#  'meggielarkin108620',
#  'rutheheidenreich130416',
#  'jodykuhn044390',
#  'sarahboehm127306',
#  'karinapowlowski171199',
#  'arnoldmann013550',
#  'chaimjacobson098841',
#  'williscremin163900',
#  'tobinchamplin017990',
#  'ciaragibson127428',
#  'adoniscorkery010209',
#  'nikoschulist163762',
#  'cletusbeahan140256',
#  'gaylegrant045078',
#  'joanawilliamson113170',
#  'kendallpadberg024162',
#  'joshschroeder149596',
#  'lelaschowalter088492',
#  'israelhoeger159194',
#  'bertrandvon051876',
#  'devontewuckert089943',
#  'deborahreichel049658',
#  'glennietowne037663',
#  'westonhane099839',
#  'donavonbeer120996',
#  'quincyspencer131614',
#  'jordiwelch089743',
#  'lenorekrajcik088098',
#  'westleyrau153467',
#  'tamararunolfsson063968',
#  'zolakirlin004170',
#  'marianeoreilly051014',
#  'larissawest168846',
#  'toneyjenkins031150',
#  'carsondurgan105173',
#  'allanbernier124575',
#  'tianagoldner136837',
#  'newtonwatsica137260',
#  'cristinaaufderhar134077',
#  'kamrencummerata148276',
#  'jarrodmraz109871',
#  'karellecremin102064',
#  'nicolockman039131',
#  'alfordkunze153186',
#  'lueabernathy153622',
#  'dellboyle057501',
#  'damienstark006313',
#  'tremainedickens152375',
#  'archibaldromaguera077716',
#  'jacksondenesik025052',
#  'elwyngreen082738',
#  'zacharyrippin102091',
#  'juliodonnelly030408',
#  'alexanderflatley094137',
#  'laurygreenholt034647',
#  'marianoupton082881',
#  'raphaelfranecki129492',
#  'brendanfisher108284',
#  'amiecartwright009597',
#  'holdenritchie097428',
#  'jaquanmorissette036025',
#  'timothyheaney035661',
#  'anitaabernathy129850',
#  'cassidyschoen158028',
#  'jevonmurphy114331',
#  'jarretlangosh125186',
#  'brandtcollins000177',
#  'wiltonreynolds126577',
#  'leannleffler016995',
#  'dayanapadberg031842',
#  'hailiehuels059527',
#  'gregoriolynch124700',
#  'cecilhintz112461',
#  'lavernafeil172595',
#  'shanellittle115621',
#  'jannieparker019956',
#  'celestinegerlach033994',
#  'johnsontowne045235',
#  'earnestcormier062931',
#  'morrislabadie088129',
#  'laurymedhurst055894',
#  'waldooconner049873',
#  'reillychristiansen045876',
#  'makaylasteuber117134',
#  'florinevon004889',
#  'tomfriesen051319',
#  'coltenjacobs026047',
#  'melbaboyer129555',
#  'vilmaokuneva082368',
#  'tremaynewiegand077725',
#  'codybruen005561',
#  'rafaelamcclure143629',
#  'landenlakin141851',
#  'guadalupeokon034901',
#  'jerrodbeahan059178',
#  'kristinbaumbach159725',
#  'oraldibbert021599',
#  'alenawuckert056615',
#  'ryleighkub118610',
#  'dangelopfannerstill092737',
#  'elliottkrajcik169835',
#  'theresekirlin107138',
#  'aldabartoletti032915',
#  'deloresstiedemann036929',
#  'elijahstreich032872',
#  'ikecremin144377',
#  'bertrandreinger167653',
#  'delilahfisher134228',
#  'alyceturner000981',
#  'jaidabartoletti122145',
#  'olliepouros134883',
#  'laurawintheiser047318',
#  'teagandietrich029424',
#  'ashtonprohaska165883',
#  'lupecrona153142',
#  'roscoelowe111674',
#  'alaynaortiz137203',
#  'lilianaharris152846',
#  'wilfredcrona065039',
#  'cliffordabshire076334',
#  'zackarygusikowski056364',
#  'carolynedickinson147146',
#  'blancheheaney042549',
#  'bradlywintheiser160770',
#  'jasonchamplin042733',
#  'hildasmitham150280',
#  'everettmraz138070',
#  'stanleymayer111993',
#  'nashtorphy163230',
#  'lizakris097604',
#  'marcokessler021297',
#  'zellaupton174001',
#  'augustakulas075437',
#  'rogerswunsch067002',
#  'abdielrussel136958',
#  'stacynolan048193',
#  'tommacgyver141080',
#  'kaylakoepp078877',
#  'reggiebins125118',
#  'altabins058613',
#  'elouisespencer109153',
#  'jeromestoltenberg090246',
#  'nehahowell115234',
#  'arianefahey039016',
#  'arvelnolan029674',
#  'myleneoconnell160181',
#  'friedrichshanahan166741',
#  'katlynnbrekke025453',
#  'jensengulgowski153320',
#  'unaklein084923',
#  'portercarroll012114',
#  'rivercormier005739',
#  'pearlinemurphy086219',
#  'willswaniawski030843',
#  'erniehoppe079640',
#  'leoskiles002399',
#  'blanchedach025047',
#  'dallincruickshank112032',
#  'misaelflatley119970',
#  'maeveleannon058504',
#  'nevamurray064571',
#  'matildarath058732',
#  'kamrynfeeney007765',
#  'tamiadickinson072919',
#  'cynthiakub066739',
#  'jacintoullrich131245',
#  'arvillabaumbach141285',
#  'ashlynnmiller005099',
#  'dorrisnicolas080554',
#  'jettiethiel039869',
#  'tessiemedhurst058092',
#  'janlesch051295',
#  'laverneheaney154459',
#  'cristopherdibbert085006',
#  'michelleledner133264',
#  'kaseykeeling044372',
#  'theodoradurgan080855',
#  'westleynader098074',
#  'lenoretromp143591',
#  'lailaklocko094141',
#  'shayneschuster032152',
#  'olinglover124974',
#  'frederikfahey087533',
#  'brodykling139047',
#  'trentbuckridge084538',
#  'elishagreenfelder030269',
#  'zariabotsford043273',
#  'vivienromaguera102467',
#  'natalianicolas021974',
#  'adelenicolas004675',
#  'joelwhite072135',
#  'gradymclaughlin120055',
#  'kayatromp057565',
#  'clarahagenes025245',
#  'sabrynadach157987',
#  'maritzapouros170315',
#  'alvahilll114303',
#  'franciscaosinski077507',
#  'levikoepp035730',
#  'tarynkohler015970',
#  'raulbarton049103',
#  'mabelrippin082906',
#  'osvaldodonnelly130105',
#  'claudinecremin022979',
#  'gilbertschoen089269',
#  'lethaconsidine081108',
#  'everettejohnston030622',
#  'altanikolaus128748',
#  'elroyromaguera035080',
#  'lennykeebler125037',
#  'katlynnlittel037040',
#  'coythiel098937',
#  'jordaneluettgen115989',
#  'ottiliesipes147159',
#  'marcelinogreenfelder135776',
#  'obieconn083312',
#  'justinalittle080073',
#  'javonbartell160319',
#  'newellschmitt000958',
#  'colinkreiger032729',
#  'halhahn099414',
#  'nicolascormier014243',
#  'estrellaaltenwerth087618',
#  'johannaltenwerth131206',
#  'tierraquigley001654',
#  'laurinemosciski079293',
#  'elmomorissette043876',
#  'yoshikokulas046308',
#  'hilarioshanahan004910',
#  'alfordgusikowski051470',
#  'daynagoyette171985',
#  'ianhansen113264',
#  'meggielockman035224',
#  'olaernser011131',
#  'goldencrooks166244',
#  'jessikahoppe008324',
#  'nolanconsidine025861',
#  'micaelabreitenberg069001',
#  'vernicemills070210',
#  'russelllittel004522',
#  'marielahaag028225',
#  'groverwatsica010301',
#  'dasiagusikowski080958',
#  'avisortiz089819',
#  'lavernmonahan019065',
#  'jevonjakubowski004662',
#  'ernestinaveum045035',
#  'schuylerschoen077767',
#  'daltonaufderhar087544',
#  'leathaklocko043304',
#  'generalbecker002117',
#  'berneiceboehm066731',
#  'garnettlang000759',
#  'zoeybartell129465',
#  'soniaanderson019521',
#  'kathrynebahringer059190',
#  'wilhelmkuhic133393',
#  'edgardorolfson022923',
#  'sheilabotsford026087',
#  'brownhand130244',
#  'wilbertrodriguez108611',
#  'simoneflatley139389',
#  'aaronkonopelski118351',
#  'jasonernser048599',
#  'vedadaugherty098544',
#  'gerryhintz113111',
#  'rosalynlehner079752',
#  'steviesimonis093740',
#  'winstonspencer140813',
#  'dameonsawayn156350',
#  'terrancealtenwerth086985',
#  'danikasteuber161173',
#  'lonnygutmann168057',
#  'jarredwalker055629',
#  'faywest163522',
#  'lululynch025677',
#  'terryhahn093936',
#  'serenalangworth153187',
#  'andresgreen141046',
#  'emiliemraz100919',
#  'esmeraldarath143229',
#  'charlotteschultz007985',
#  'pipersteuber026978',
#  'alejandramarquardt111652',
#  'zoilawolff165541',
#  'boebert138200',
#  'manleyokon068469',
#  'mustafakoepp145725',
#  'monserratboyer147664',
#  'bessieboyle152953',
#  'stanheller054989',
#  'tonygreenfelder158289',
#  'ignatiushahn059564',
#  'lexiekulas002920',
#  'christopherbechtelar142891',
#  'jamisonledner001678',
#  'vellavandervort057239',
#  'orphahammes102938',
#  'wilbertgreen021005',
#  'deshawngibson077044',
#  'edgardowolf077210',
#  'estellekautzer003257',
#  'wellingtonhowe044112',
#  'shaniyamertz138081',
#  'loranader104927',
#  'yolandaleffler042452',
#  'joanbatz053410',
#  'rachelklocko096853',
#  'dejuanprice147507',
#  'alenekub048621',
#  'yesseniahaag006935',
#  'gersonlakin056603',
#  'katrinathiel083607',
#  'mitchellgottlieb055378',
#  'raeganleannon057251',
#  'estelladubuque037106',
#  'tamiakozey007634',
#  'jeremyhudson092859',
#  'preciouschamplin112778',
#  'deannaryan094092',
#  'ashaemmerich163855',
#  'jovanihirthe069370',
#  'orincrist104172',
#  'bayleeemard169952',
#  'wallacehegmann167184',
#  'georgetterau053726',
#  'montygrimes162989',
#  'earlbahringer072933',
#  'graciebuckridge170353',
#  'coleadams097259',
#  'claudeparisian010201',
#  'felipeschuster050265',
#  'robertobaumbach026880',
#  'llewellynschmeler008215',
#  'isaiahgulgowski142553',
#  'janelleondricka010527',
#  'ashtynfranecki101678',
#  'jacklynsteuber057714',
#  'michaelcremin017993',
#  'juddjakubowski120822',
#  'salvadorschneider164520',
#  'ressiefunk082542',
#  'codyfeest113322',
#  'carliecarroll114117',
#  'erickgoyette103539',
#  'rachelstracke172756',
#  'gertrudeparisian037212',
#  'ansleymurray141058',
#  'mckaylakub150676',
#  'kimhagenes039027',
#  'jerryhagenes041185',
#  'laureljohnston018822',
#  'darrinrath022183',
#  'camronrohan140750',
#  'barryschoen001785',
#  'clemmiehilll167353',
#  'gersonbosco161120',
#  'elseheidenreich096796',
#  'antoniettawhite038071',
#  'herminagoyette142643',
#  'ninaoreilly110998',
#  'fridafeil103864',
#  'gabriellacrona007362',
#  'velmastrosin048618',
#  'allanrussel051356',
#  'jovandicki059599',
#  'merladams167126',
#  'mikaylagorczany108733',
#  'korythompson081005',
#  'alysadooley057106',
#  'tyshawnblanda165270',
#  'staceyoconner172992',
#  'miguelmacgyver037730',
#  'lancemaggio035733',
#  'brooklubowitz149556',
#  'mabelbrekke097236',
#  'clemmieschiller039054',
#  'haileeferry049857',
#  'chynanader104699',
#  'ashtynfritsch151283',
#  'boydlarkin000354',
#  'aureliesmith141922',
#  'staceywintheiser051289',
#  'antwonjacobs080122',
#  'leonardocummerata078951',
#  'elroybatz065340',
#  'bentontillman074527',
#  'clairhansen116899',
#  'verniejakubowski115269',
#  'maudhowe069762',
#  'annabelmonahan037215',
#  'shyannemarks036044',
#  'lianaoberbrunner170682',
#  'terrancemoore118353',
#  'averybeier152634',
#  'pearlinechristiansen042691',
#  'sonyabraun151362',
#  'kristofertorp107735',
#  'vinniehuel064401',
#  'berenicemonahan138641',
#  'brandylangosh068379',
#  'wymanauer011004',
#  'elenorafeest012920',
#  'bernhardlind149966',
#  'joyosinski014437',
#  'estabeatty056398',
#  'lurlinecartwright117037',
#  'kavonvon005689',
#  'gaetanoglover008114',
#  'sonialueilwitz023459',
#  'keltonschamberger047315',
#  'mariahickle094985',
#  'ozellathiel085914',
#  'lucileschamberger089546',
#  'huberthuels069930',
#  'myrtiestracke173191',
#  'owenbuckridge133016',
#  'martawolf132099',
#  'myadenesik083943',
#  'dagmarwolff079810',
#  'luisarowe050529',
#  'jonasmonahan075280',
#  'filomenabreitenberg164420',
#  'ilakohler117140',
#  'magnoliamcclure027342',
#  'emmaprohaska027271',
#  'kieranschaden080081',
#  'michaeladouglas081223',
#  'darylherman163819',
#  'zacherysteuber014981',
#  'gildamosciski103069',
#  'alecjacobi055904',
#  'cassandrawest128340',
#  'ernestinewiegand073923',
#  'nasirbeer024804',
#  'cristobalbogisich134142',
#  'hermannschuppe123959',
#  'guiseppeheller075815',
#  'colbyhand065743',
#  'sarinakertzmann086152',
#  'judgehilll154101',
#  'camrondenesik066598',
#  'kathrynkreiger082616',
#  'lavonnegutkowski080325',
#  'colbydubuque072068',
#  'leopoldohand037750',
#  'modestokiehn147252',
#  'alysonpfeffer153721',
#  'luismaggio082996',
#  'jessicarunolfsdottir115162',
#  'alvahhintz134417',
#  'rexrempel071154',
#  'elisaokeefe049015',
#  'maevegoodwin162963',
#  'shanekassulke132251',
#  'kaylagrimes032581',
#  'lilamiller168804',
#  'marcellerath031098',
#  'zachariahraynor131299',
#  'melissawilliamson121442',
#  'enochbartoletti103235',
#  'westonvolkman068055',
#  'ricardobrekke097934',
#  'maxineadams064662',
#  'jamisonankunding061254',
#  'angelicathiel057525',
#  'elvajones100176',
#  'ottiliehoeger005322',
#  'lemuelmuller113760',
#  'stanjaskolski001172',
#  'darrelmiller017629',
#  'earnestgerlach127836',
#  'kevenmoen042393',
#  'albertamiller060129',
#  'reaganwhite148241',
#  'toystokes161186',
#  'joreichert155241',
#  'elvastreich039317',
#  'juliusbrakus153271',
#  'budledner165092',
#  'floridaosinski098398',
#  'tyshawnmcdermott158559',
#  'karsondamore157401',
#  'loycefarrell146245',
#  'patrickfarrell131106',
#  'webstercrona060124',
#  'mariellemclaughlin045497',
#  'lolitabeatty066999',
#  'berniecejast023601',
#  'eliezerupton077183',
#  'helmerhilll121002',
#  'erlingschuppe088625',
#  'oceanemitchell075049',
#  'dennissenger052507',
#  'delphiadoyle141502',
#  'werneroberbrunner133734',
#  'consuelohaag160036',
#  'cordellturner101742',
#  'osbaldotreutel072785',
#  'charityboyle096474',
#  'daxkertzmann095374',
#  'nellaondricka149637',
#  'clementinakeebler083011',
#  'jeaniedavis063070',
#  'billyschroeder135254',
#  'maximilliacorwin130923',
#  'sigridlowe040296',
#  'emmyschaefer117309',
#  'ruthiewest068995',
#  'alecbeier109737',
#  'mackhayes053838',
#  'pablokoss166411',
#  'elvarowe049269',
#  'lauriepurdy162601',
#  'cornellmueller011958',
#  'zoragrady023762',
#  'denispurdy164132',
#  'levikonopelski049956',
#  'erichrobel060995',
#  'jabarimertz116434',
#  'adriannavon143242',
#  'gustkuhlman071666',
#  'karaschuppe076554',
#  'lynnbogisich110323',
#  'isomsauer151492',
#  'sterlingbahringer164705',
#  'tillmanlarson080735',
#  'alexandreaokuneva049470',
#  'ashtonyost005220',
#  'robertahills167248',
#  'armanistanton044083',
#  'idelltrantow163124',
#  'annamarielittle129799',
#  'emelycarroll077297',
#  'jamesonweimann093257',
#  'lennakoch120728',
#  'tiannablick112536',
#  'lupegulgowski138600',
#  'sincereschulist070515',
#  'cortezbuckridge052611',
#  'giannigutkowski074491',
#  'lilianarowe158433',
#  'marcoshuels130143',
#  'petehirthe033504',
#  'sarinathompson050170',
#  'abelauer112918',
#  'mossiebruen154711',
#  'baileybotsford124567',
#  'jessieconroy069599',
#  'marcusgoodwin069452',
#  'dannycartwright026816',
#  'alexandertowne142422',
#  'isaikeebler107544',
#  'orvillerobel048275',
#  'burdettegutkowski155336',
#  'earlinemcdermott092581',
#  'reillybeatty110952',
#  'hilbertpaucek037467',
#  'unahintz064921',
#  'clintonaltenwerth073531',
#  'alfredfeeney065869',
#  'wilberkuvalis020685',
#  'amelykeebler111969',
#  'ruthiebrown071628',
#  'ryleywalter058184',
#  'eliseopowlowski151052',
#  'alphonsoromaguera116554',
#  'elnoraschroeder006293',
#  'norbertward115367',
#  'chelsiesmith166769',
#  'adrainwindler174074',
#  'edgarkunde139813',
#  'willareynolds097152',
#  'bransonwill023704',
#  'gussiewisozk034051',
#  'rebekahschumm080679',
#  'rodrigokoelpin061951',
#  'vinniemccullough159794',
#  'helmerkirlin094608',
#  'brandonbergnaum089725',
#  'cedrickvonrueden006036',
#  'carliehodkiewicz045271',
#  'korbinstoltenberg139739',
#  'gudrunhomenick013815',
#  'aronwolff091072',
#  'wellingtontoy157964',
#  'giapowlowski140148',
#  'ovarussel159840',
#  'chasebosco025483',
#  'chaimkovacek004373',
#  'alexysrempel158164',
#  'bethbarton075518',
#  'mistyhansen085886',
#  'dinamayert145925',
#  'clarissabrakus144541',
#  'mosesstark171669',
#  'marcelhansen004879',
#  'dejagislason150729',
#  'kendrickblanda095873',
#  'sibylthiel074544',
#  'florenciodubuque038579',
#  'brodywillms135022',
#  'sierrapurdy080041',
#  'romancorkery004724',
#  'cathynolan005356',
#  'efrainskiles080826',
#  'julierohan094625',
#  'noewilderman119444',
#  'carmelmiller143008',
#  'davonpurdy013685',
#  'lavernacummings104572',
#  'maribelprosacco084318',
#  'arlenehowell128570',
#  'meaganjacobi045611',
#  'daltonfranecki143313',
#  'fannykunze071861',
#  'kingbayer040361',
#  'georgettewaelchi085333',
#  'dedrickbartell021504',
#  'garthwhite005733',
#  'mckaylazieme032158',
#  'deionleffler024540',
#  'humbertocarter004666',
#  'marleereichert078161',
#  'jovanybahringer137732',
#  'trevalangworth086147',
#  'vitafeil140569',
#  'missouribode110105',
#  'addiebins097194',
#  'concepcionosinski033577',
#  'delbertkub135395',
#  'stellabernier136759',
#  'justineferry048231',
#  'neomawest148689',
#  'coopermante065768',
#  'candelariokoss088424',
#  'loycesanford092073',
#  'dionmarks007686',
#  'tristianwolf004254',
#  'johnniehand018231',
#  'loyalondricka109046',
#  'katelynnwunsch171031',
#  'ephraimolson014613',
#  'heidiziemann135733',
#  'kyrashanahan024864',
#  'rasheedgreenholt032613',
#  'queenthiel004350',
#  'halskiles088125',
#  'kyliewalter036739',
#  'augustprice146643',
#  'margretwhite166597',
#  'rockydonnelly160692',
#  'floyborer116990',
#  'caylaruecker104220',
#  'hudsonheller012738',
#  'trinityledner101320',
#  'albertowuckert157968',
#  'danemckenzie064096',
#  'lionelprosacco132106',
#  'brucelittel005343',
#  'rodolforatke141041',
#  'alekvolkman160352',
#  'venaparker133913',
#  'marianneauer046697',
#  'kathlynparker130341',
#  'reginaldluettgen127326',
#  'jackybrekke147553',
#  'gracielaschmidt038631',
#  'destineyhegmann079630',
#  'zelmatorp133209',
#  'ryannsmitham025828',
#  'moshemayert108207',
#  'erichbednar004701',
#  'marlenemoen036673',
#  'maryprohaska105537',
#  'retalesch067349',
#  'myriamschowalter053302',
#  'marlinkuhn171652',
#  'marysehudson158935',
#  'wilburnoconner005157',
#  'brianbarton037460',
#  'daisyschmeler112427',
#  'wadehodkiewicz052036',
#  'kathlyngaylord077391',
#  'kennediebert091627',
#  'manuelahowell092740',
#  'clementinespencer070736',
#  'aidenkovacek090426',
#  'lincolnblick125728',
#  'caterinakertzmann113689',
#  'kellenupton127854',
#  'keonbergstrom017472',
#  'joycegutmann077039',
#  'eloyhilpert132307',
#  'lucyaufderhar174194',
#  'mabelbarrows039908',
#  'josiahgraham061007',
#  'yvonnepouros088807',
#  'caterinametz051924',
#  'clevelandbernier003207',
#  'berneicemayer090546',
#  'magdalenapurdy004048',
#  'lambertblick010787',
#  'melanykuphal129209',
#  'deltaankunding006382',
#  'florinevonrueden065313',
#  'blancheborer093714',
#  'heatherchamplin165098',
#  'milescasper136063',
#  'tylerwintheiser059870',
#  'carolynestracke060076',
#  'nyahgerlach029968',
#  'laylamraz142699',
#  'gerryabbott141420',
#  'maxsipes167378',
#  'ezekielchristiansen063875',
#  'dellbailey002345',
#  'keyonlockman124080',
#  'marcellawolf085275',
#  'myronrogahn017541',
#  'caseypfeffer094238',
#  'christopherbecker158215',
#  'candacecummerata147675',
#  'javontebraun025557',
#  'parisadams107916',
#  'shawnaabshire038843',
#  'gardnerwalsh162687',
#  'henriprice086269',
#  'ozellalittle157772',
#  'austindavis147681',
#  'vernerbode064995',
#  'maryamluettgen007571',
#  'lianakeeling123313',
#  'metareichert166095',
#  'joannymueller101588',
#  'graycekshlerin142388',
#  'carlosabbott079350',
#  'rafaelsipes001534',
#  'elodyharris046934',
#  'leliahowell164255',
#  'euladubuque004774',
#  'melanyhoeger107383',
#  'rosalialeuschke080957',
#  'geraldinegaylord053010',
#  'darianoberbrunner110063',
#  'lavonfeest059195',
#  'wendyfeil100598',
#  'demarioklein143956',
#  'jazminsmith148844',
#  'mikaylawilderman035132',
#  'dellmacejkovic079505',
#  'astridstamm066838',
#  'antonionolan110195',
#  'lamontgerlach049740',
#  'sabinawest054312',
#  'jacquesjakubowski107291',
#  'shirleynader107734',
#  'einostroman102300',
#  'wendellzieme124630',
#  'queeniegerhold153376',
#  'keelybecker041536',
#  'herthareynolds146299',
#  'hilariowisozk058879',
#  'delmerleuschke121844',
#  'adeliaquigley168631',
#  'anaiswilderman069803',
#  'danielastoltenberg092501',
#  'theronglover041881',
#  'furmanleannon077905',
#  'delfinaveum100526',
#  'marjoryluettgen098225',
#  'rosalindadooley073922',
#  'johanveum029655',
#  'eileenstreich087020',
#  'watsonryan174799',
#  'frankieglover002771',
#  'rickeyjerde071282',
#  'rebekahdonnelly087204',
#  'dejonrau111180',
#  'ruthieritchie044009',
#  'frederickgoldner062171',
#  'paytonfisher093305',
#  'maximilliadibbert165988',
#  'isabeldibbert100401',
#  'jamalwiegand019476',
#  'herminiaauer083867',
#  'amyatreutel116784',
#  'bettiehermiston018074',
#  'kayleighschmitt089663',
#  'rowanconnelly089052',
#  'jadonmorar158400',
#  'lempischimmel127674',
#  'adriannawalter134010',
#  'eastontromp149701',
#  'adeliaharvey109416',
#  'thalialueilwitz035980',
#  'jaysonrogahn110469',
#  'eldonnader135545',
#  'alysonmorar087463',
#  'joanniewelch042823',
#  'garthheaney108536',
#  'sedrickfarrell119164',
#  'melanybeatty000926',
#  'alyost162875',
#  'alysongraham058509',
#  'simonedurgan135727',
#  'laurenkunze021094',
#  'reesekutch119408',
#  'lorenokeefe067670',
#  'laishafritsch081012',
#  'graciefeest171994',
#  'bradyhoppe086036',
#  'wernerwillms105915',
#  'carleekutch088564',
#  'victormckenzie089124',
#  'liawhite037917',
#  'carletonkling036315',
#  'armandhegmann080768',
#  'alessandrobuckridge061370',
#  'eddohara162175',
#  'racheljohnson051758',
#  'horaciokoss139831',
#  'yvettewalker109458',
#  'hughnicolas066914',
#  'lorenhowe080635',
#  'jaydawaelchi064237',
#  'cortneybahringer157162',
#  'laurynwilkinson129809',
#  'susanadaugherty028669',
#  'mariloudouglas074792',
#  'peggiehoppe027823',
#  'libbierau039662',
#  'jensenmacgyver026456',
#  'fredrickspinka058862',
#  'jammieschaden113967',
#  'anyalarkin154319',
#  'zakaryspencer053696',
#  'jeromyfeeney004356',
#  'conradkohler099761',
#  'louiecarroll056241',
#  'adellagrady043978',
#  'novellaleuschke008721',
#  'jackelinerobel008259',
#  'olaftreutel002040',
#  'tessiekirlin124660',
#  'codypollich082655',
#  'leebartoletti115637',
#  'ignaciorobel082395',
#  'jamiekunde012776',
#  'mariohuels069231',
#  'mayelindgren138179',
#  'nigelbode038379',
#  'hopegorczany021695',
#  'bernadinecruickshank118962',
#  'neldawalker115721',
#  'ruthieschaefer057720',
#  'hestercorwin089640',
#  'genechamplin039025',
#  'veldakassulke100232',
#  'levicollins122277',
#  'willowdamore150863',
#  'adriankovacek158774',
#  'tianafadel121523',
#  'angelbarrows055821',
#  'chelsielueilwitz033968',
#  'dedrickheaney023317',
#  'fordlemke087447',
#  'daphneelittel014451',
#  'granvilletremblay108991',
#  'gerryrippin011241',
#  'percykertzmann049541',
#  'brooksgoldner019810',
#  'nedlangworth130515',
#  'toneygrant046946',
#  'constancehackett156795',
#  'ashleyharvey057031',
#  'aidanikolaus166475',
#  'jedidiahwill152763',
#  'amelymohr035848',
#  'inesprosacco051221',
#  'ferminankunding071685',
#  'myabechtelar143371',
#  'katlynohara142127',
#  'kayceelebsack174302',
#  'antonionolan075756',
#  'hoytturner098954',
#  'rachellealtenwerth063576',
#  'donaldkilback105687',
#  'magdalenanolan122976',
#  'abdulcasper168646',
#  'deewiza033713',
#  'phoebeprohaska007801',
#  'raquelherzog068504',
#  'aurelieschamberger166801',
#  'demarcoromaguera017411',
#  'alejandrinnader014774',
#  'berniedach109857',
#  'miltonstark020240',
#  'carolenicolas130288',
#  'baileycremin021107',
#  'amyajohnston115560',
#  'shaynamcglynn054456',
#  'sophialangworth166664',
#  'kyliedeckow112048',
#  'anitabergstrom125580',
#  'kianaskiles101292',
#  'jordaneskiles124908',
#  'kayahowell086457',
#  'maureenchamplin039112',
#  'keiraflatley135515',
#  'rosemariemarks044202',
#  'kalebcollins067069',
#  'halleschultz172722',
#  'gildachamplin007106',
#  'pansyherzog029401',
#  'carolhackett028008',
#  'amanijakubowski115157',
#  'sheridanjacobi000220',
#  'shanelbosco138917',
#  'tobycremin112146',
#  'cristalankunding071293',
#  'brycerussel011962',
#  'estherweissnat122474',
#  'nedrakeebler066299',
#  'gailhickle103577',
#  'emelieyost041398',
#  'sydnicummerata013559',
#  'yeseniagrady067325',
#  'santinotoy133417',
#  'blaisekshlerin000429',
#  'lelandmitchell063198',
#  'lexieerdman143889',
#  'estamosciski027403',
#  'domenicacormier141415',
#  'damionsmitham110147',
#  'berneiceoconnell087979',
#  'agustinconnelly098664',
#  'theoerdman167027',
#  'amaramayert103388',
#  'jacquesglover092122',
#  'layneblock119062',
#  'mabellenienow108445',
#  'joanahuel004393',
#  'santosblanda089384',
#  'newtonrunolfsson004098',
#  'lavadahamill015925',
#  'carmellaoreilly001727',
#  'kaciebode168537',
#  'johannabosco155400',
#  'gwenharber014017',
#  'kamrynsmitham000325',
#  'justinebeier146360',
#  'caleighweimann056645',
#  'busterframi166243',
#  'staceyoberbrunner168394',
#  'bartkris112709',
#  'lanemante037135',
#  'amalialindgren053708',
#  'hubertkozey172104',
#  'dawsonwillms017856',
#  'arnebotsford071054',
#  'kennithpurdy140719',
#  'moshedurgan095165',
#  'kamrenschuppe132815',
#  'damondach120623',
#  'adelaconn155902',
#  'johnschinner168598',
#  'allenekunde044805',
#  'hattiecassin000866',
#  'jovannymcdermott144871',
#  'albinaledner059206',
#  'johnnystrosin047213',
#  'elenorolson096217',
#  'adrienwalsh143781',
#  'carlosfay028358',
#  'lennienikolaus008474',
#  'elzawisoky169964',
#  'hymankunze027524',
#  'jamircormier032769',
#  'rigobertolockman025716',
#  'vitapowlowski051615',
#  'kendraluettgen026977',
#  'tedfeest073081',
#  'geraldthompson039365',
#  'everardoveum011350',
#  'ulicesstark123117',
#  'claradietrich138062',
#  'rashadkutch089103',
#  'tyshawnhamill130126',
#  'albertohettinger005273',
#  'isaikreiger038630',
#  'josephinegleason033509',
#  'claudekoch132779',
#  'vitomoore145007',
#  'madysonstehr099985',
#  'elroyluettgen003268',
#  'joaquinnader005688',
#  'wellingtonhowe148162',
#  'adelalehner160947',
#  'jonathondouglas143581',
#  'jeanetteerdman145620',
#  'einokub129154',
#  'cameronreichert089826',
#  'gregbruen072692',
#  'kirstenbins109331',
#  'ledareynolds136242',
#  'joanagoyette115223',
#  'reillylebsack121440',
#  'chaimcummerata037736',
#  'kaileelehner091769',
#  'soniaglover050829',
#  'tremaynenader117173',
#  'bradleyhackett169657',
#  'keatoncremin056893',
#  'savanahjohns058814',
#  'marcgraham007005',
#  'jalenschulist069483',
#  'savannahcormier084109',
#  'germainelowe035923',
#  'janickleannon035548',
#  'brianward119022',
#  'rosaliagerlach131276',
#  'valentinking018963',
#  'brannondoyle088253',
#  'chanelbartoletti168485',
#  'kendrickwaelchi007024',
#  'laruemedhurst054912',
#  'kaceykeeling060342',
#  'rosariomcdermott096594',
#  'lucianogottlieb110284',
#  'karliconroy159449',
#  'marcelgrady164939',
#  'margaretewyman075070',
#  'theresenikolaus013972',
#  'wilberkihn053212',
#  'kileygutmann007793',
#  'clovistreutel166913',
#  'lennysauer172606',
#  'domenicaemmerich066334',
#  'kristincole045552',
#  'elenorrempel020666',
#  'fideldach114224',
#  'makenzieyundt001406',
#  'lillyferry059245',
#  'leraoreilly002404',
#  'kianaschmitt004411',
#  'patryan007546',
#  'moshebernier100366',
#  'rosaliatoy000359',
#  'lukasdickens128951',
#  'aylawilkinson043494',
#  'tabithadickinson078004',
#  'joellewunsch089380',
#  'alvinaterry077998',
#  'caesaroconner001797',
#  'deronschulist160625',
#  'noemyrogahn129599',
#  'avisbeatty162564',
#  'albinbrekke024020',
#  'madalynzboncak024534',
#  'laurettapfeffer139658',
#  'claudineterry102493',
#  'tituspowlowski173420',
#  'laneyschimmel050708',
#  'benlindgren174609',
#  'gisselledibbert063448',
#  'antonettabogan151822',
#  'reannashields149227',
#  'miltonmccullough137297',
#  'stanlakin042606',
#  'abelstehr034128',
#  'maxiekassulke115373',
#  'jakenienow098681',
#  'josianechamplin011272',
#  'rickfritsch071486',
#  'heavenhuels042243',
#  'kendrickjerde095274',
#  'juniusschiller044596',
#  'ressiebode077260',
#  'dasiawilliamson000855',
#  'edythebraun042621',
#  'sarinaspinka117129',
#  'jaynechristiansen168131',
#  'aleccollins081067',
#  'deshaunreichel082498',
#  'kaseyreynolds122779',
#  'turnerhickle164794',
#  'kyleevon087153',
#  'alejandrawiegand172084',
#  'daleward138672',
#  'jacquelynbashirian174456',
#  'jolieboyer113624',
#  'gradydickens148108',
#  'alysawillms027631',
#  'germainestehr080609',
#  'elyseconsidine027115',
#  'meredithgraham111942',
#  'flaviedonnelly063954',
#  'jettwindler123921',
#  'lysanneoconner000670',
#  'wilfordkeeling063787',
#  'bospencer021240',
#  'kayagerhold058419',
#  'clairmurazik144615',
#  'elodybergstrom113424',
#  'briellereynolds025790',
#  'ezequielklein087548',
#  'ambrosereynolds164793',
#  'doviewill171645',
#  'angelicazboncak163140',
#  'albertokeeling106505',
#  'constancedickens074375',
#  'mittiefeest078407',
#  'aureliemueller121571',
#  'faustobotsford014683',
#  'eugeniajones061887',
#  'maxinejohns098410',
#  'zanekeebler152357',
#  'alizejenkins014238',
#  'fletagreenfelder028374',
#  'clemenswaelchi092562',
#  'kurtispowlowski041160',
#  'tamarawaelchi087351',
#  'laurynthiel054062',
#  'katrinekemmer006759',
#  'trudielind063353',
#  'odiedavis055138',
#  'alexzanderstroman095022',
#  'lincolnoberbrunner024559',
#  'shanelstehr117424',
#  'kieranroberts060891',
#  'rethaprice042386',
#  'christschneider120368',
#  'durwardpadberg121740',
#  'jaylenthiel149545',
#  'ceasarblock114850',
#  'wilfredveum043861',
#  'jacquelynkulas125819',
#  'ransomhessel074711',
#  'jameypurdy057790',
#  'dangelofritsch049088',
#  'simpowlowski075690',
#  'alexandrinemarquardt135636',
#  'allymacejkovic096455',
#  'rosekemmer011961',
#  'niahartmann128434',
#  'patriciathiel045304',
#  'garnettkuvalis123136',
#  'amandahyatt123324',
#  'marquisschoen065484',
#  'lylalarkin047880',
#  'coralangworth162146',
#  'alanisortiz044494',
#  'victorcasper164143',
#  'mariambrakus013680',
#  'dustinkuphal030766',
#  'rileylockman137362',
#  'aglaecummerata146565',
#  'sedrickbayer101556',
#  'cortneystreich139612',
#  'ethylstehr105743',
#  'johnsonzboncak045538',
#  'filomenafeil002559',
#  'davonbechtelar026890',
#  'myaswift139038',
#  'camdenmills145798',
#  'hiltonhills005326',
#  'maribelratke107067',
#  'winnifredvandervort090567',
#  'lucienneemard163805',
#  'percysenger063596',
#  'leonespencer022556',
#  'jaredfritsch079813',
#  'norrisjacobs121395',
#  'tyriqueschmeler064328',
#  'meghanwhite095199',
#  'laverneokon065424',
#  'ruthieroob041010',
#  'zackarycarter172222',
#  'ovavon036844',
#  'jarodsenger095765',
#  'ikehintz089915',
#  'rodolfodamore112700',
#  'vitobarrows162609',
#  'sasharaynor169105',
#  'matildamayert104201',
#  'quintenbrekke001741',
#  'jayceankunding114431',
#  'marcelorosenbaum060194',
#  'athenawiegand092580',
#  'eliasupton047070',
#  'wilhelmschneider106547',
#  'hilarioromaguera042511',
#  'brianjacobson124332',
#  'carlieleannon073650',
#  'geodavis106414',
#  'joycerolfson077239',
#  'michaelaharber066196',
#  'enostoy020845',
#  'euniceraynor068442',
#  'melyssagerlach112310',
#  'lucindajacobs026291',
#  'kendrickwisozk170960',
#  'louhoeger075381',
#  'kyliefisher119246',
#  'sidneystokes153567',
#  'patiencebartoletti157104',
#  'xzavierbrakus062811',
#  'miaokon154587',
#  'alaniscole139973',
#  'torreyrolfson104990',
#  'scarlettmarquardt170466',
#  'roderickpaucek082264',
#  'susierogahn035060',
#  'aurorewolff077370',
#  'elmirawalsh117775',
#  'marcelupton130555',
#  'adeliasatterfield018037',
#  'enidgutmann022178',
#  'victoriasmith042782',
#  'isomherzog064712',
#  'raulsipes029940',
#  'eliyost024407',
#  'rowlandbailey066985',
#  'camronbeatty102033',
#  'angelwatsica128646',
#  'anitahuels146132',
#  'nicholasrussel158512',
#  'lerahansen017445',
#  'vicentebahringer064946',
#  'jonatanfeil095240',
#  'lilyfranecki034692',
#  'emeryzulauf089793',
#  'brandtkuhic169203',
#  'sallyankunding014500',
#  'samirtillman081235',
#  'dalepollich110594',
#  'anitazieme055695',
#  'evansanderson108682',
#  'rahulshields132679',
#  'ednastoltenberg081033',
#  'fernebeahan050071',
#  'brianokeefe090505',
#  'bernardobergnaum043767',
#  'alfreinger121161',
#  'dangeloromaguera132118',
#  'royalmacejkovic014594',
#  'stanleygraham070594',
#  'bobbyorn162741',
#  'magnoliaroob161584',
#  'jakegutmann132591',
#  'isidroschneider172088',
#  'allykuphal115506',
#  'marilyneoconnell040695',
#  'isaacmaggio173270',
#  'madisynwunsch040593',
#  'josepharmstrong020720',
#  'willardgoodwin040565',
#  'esmeraldacorkery021396',
#  'michaleprohaska106621',
#  'wilfredschulist115687',
#  'shyannedooley003116',
#  'virginiamurray089571',
#  'jeromyschimmel124931',
#  'tomasberge153829',
#  'alexzandertowne164673',
#  'mylenestrosin001335',
#  'keanuhyatt026330',
#  'viviennecollins108544',
#  'uriellittle073517',
#  'abrahamlang082001',
#  'pamelawilkinson149338',
#  'jerrodspinka161523',
#  'wilmalang036237',
#  'kipbarton123424',
#  'elzalockman137268',
#  'krystalkuhic043664',
#  'lavernachristiansen140180',
#  'busterbecker119990',
#  'goldahayes048828',
#  'nathanharvey122678',
#  'bridgetconn171542',
#  'everettlittle119066',
#  'javierhilpert048396',
#  'frederiqueschaden162814',
#  'jeffereyschinner049916',
#  'bennyschmeler025111',
#  'gisselleschaden151928',
#  'tressietrantow130917',
#  'patsyhirthe130794',
#  'veronicablick016283',
#  'milfordbrown029144',
#  'milesstreich053173',
#  'ahmederdman125087',
#  'arlokoepp142704',
#  'chaselowe104385',
#  'thoramoen000070',
#  'roycetowne102108',
#  'phoebemayer003276',
#  'jeaniestanton110189',
#  'colehoeger147921',
#  'madonnabauch035840',
#  'winonastiedemann068180',
#  'delphineconn086391',
#  'stantonbarton081407',
#  'brittanylabadie075311',
#  'linneafunk089810',
#  'levijohns071633',
#  'marianeschuster020035',
#  'santinocummings149577',
#  'marjorieswift084418',
#  'enriquekeeling126674',
#  'heavenkutch006523',
#  'alvenawuckert098361',
#  'reesemurazik133215',
#  'tremaineroob064971',
#  'lindahowe019614',
#  'flavioeichmann035287',
#  'grantschmidt017331',
#  'tatehuel042151',
#  'maynardschamberger116376',
#  'ariellelang148623',
#  'kaylismitham030855',
#  'emelybreitenberg028856',
#  'justenbailey159624',
#  'braxtonspinka106470',
#  'syblemccullough109792',
#  'rosiewolf010908',
#  'saigenitzsche139073',
#  'minahilll091345',
#  'gustavekertzmann082289',
#  'milozieme163316',
#  'elenorschoen003921',
#  'celinealtenwerth031233',
#  'rashawntromp011760',
#  'ludiespinka037142',
#  'quentincollier002432',
#  'delbertharris128202',
#  'ernestineschaefer159738',
#  'ikekirlin172361',
#  'marqueskoepp163393',
#  'jeaniebeier105143',
#  'mackenziebeer157545',
#  'imogenehills159330',
#  'annagerlach159908',
#  'ervinjacobs158570',
#  'koreyprice017120',
#  'wilhelmgoodwin097519',
#  'idellraynor137897',
#  'carlottadach061015',
#  'katrinabecker063028',
#  'judgerogahn160241',
#  'edgardozulauf038245',
#  'moseschoen100809',
#  'orrinhintz077617',
#  'ricoquitzon096804',
#  'evechamplin093872',
#  'kennaratke161435',
#  'rociocorkery157073',
#  'annettablanda100617',
#  'jeannerolfson163607',
#  'dustinrussel166381',
#  'stacystamm109469',
#  'floridabraun037964',
#  'constanceschinner007213',
#  'tatyanadonnelly044485',
#  'forrestschowalter027919',
#  'cesarbarton156547',
#  'verdieheaney075333',
#  'elveraharris062218',
#  'lawsonabbott126063',
#  'gretaharvey087685',
#  'darronbode140055',
#  'ashlybergnaum148467',
#  'marisalehner091150',
#  'reecedietrich155227',
#  'reesegoldner134784',
#  'gailmoore005269',
#  'daijatremblay126904',
#  'arnulfojacobs138570',
#  'beauschultz170422',
#  'osbaldogreen140058',
#  'louisadouglas098499',
#  'jeangreenfelder118214',
#  'kaitlingottlieb097054',
#  'yvonnewisozk133939',
#  'kendrickfunk162729',
#  'kayglover001005',
#  'nathanbergnaum092445',
#  'octaviamiller172523',
#  'robinwalsh170047',
#  'karinaschimmel009530',
#  'dustinhills065197',
#  'sydneylynch099419',
#  'terrelldonnelly156539',
#  'genelind042181',
#  'karifarrell130939',
#  'lelamcglynn026649',
#  'brandttreutel172564',
#  'brandofeeney050902',
#  'houstonnienow171213',
#  'hopebraun157195',
#  'deondrejones112251',
#  'edreilly139123',
#  'ernaortiz091937',
#  'isidrocorwin074405',
#  'dejawehner160621',
#  'marawatsica162629',
#  'havenkrajcik146192',
#  'ronaldomoore051100',
#  'williamcrona156081',
#  'olincasper104434',
#  'bertrandlebsack083099',
#  'roselyngoodwin150045',
#  'birdiereichel087588',
#  'owenturner137221',
#  'lelabins108723',
#  'dejahrempel088604',
#  'cynthiawilderman047260',
#  'tomasagorczany113446',
#  'mertielabadie169029',
#  'einocorkery132477',
#  'noesmitham001939',
#  'cristalhahn117170',
#  'vedalemke119888',
#  'elishasanford008285',
#  'colegusikowski032284',
#  'sadyemraz024680',
#  'lornagrady132967',
#  'lavernebergnaum026229',
#  'lesleywisozk162932',
#  'christophesawayn151446',
#  'clarebreitenberg172103',
#  'thaliahilll153816',
#  'myleneabbott091176',
#  'christophegutkowski001293',
#  'lincolnkuphal087289',
#  'carloerdman032537',
#  'wilfredohalvorson166569',
#  'carlozemlak131218',
#  'gwenyost137490',
#  'tryciasawayn047235',
#  'dandrekoelpin113763',
#  'evelynaufderhar112947',
#  'othabailey054624',
#  'jamirrunte040550',
#  'lacymorar012262',
#  'marcritchie110085',
#  'jordankub049831',
#  'chynakutch030911',
#  'arturookon158623',
#  'nellekshlerin052143',
#  'rubiemacgyver109681',
#  'orvillelueilwitz111836',
#  'ottiliedouglas122198',
#  'adolphkeeling065770',
#  'jakedavis096013',
#  'buckokeefe173200',
#  'susannapagac120594',
#  'christianacummings159315',
#  'freidagoldner142469',
#  'tamiaschuppe053313',
#  'gavinschneider114921',
#  'jabarileffler154454',
#  'orphacrist083909',
#  'dessiebrown153067',
#  'kiaramcdermott173974',
#  'aronprosacco090266',
#  'crawfordsmith112525',
#  'isidrobarton109956',
#  'christypacocha001167',
#  'luciennelittle124467',
#  'zeldaarmstrong045094',
#  'jaredbode039608',
#  'selinacronin084240',
#  'okeysatterfield105357',
#  'ivahhansen063509',
#  'eugenemcglynn143484',
#  'mallieeichmann112085',
#  'duncanbalistreri106806',
#  'lawsonkihn025743',
#  'robynsawayn022650',
#  'hayleegorczany158283',
#  'ethelynswift163370',
#  'rafaelasipes037859',
#  'lynnrenner124423',
#  'luluschoen009385',
#  'mackenziepagac156341',
#  'kittykiehn016052',
#  'earlineheidenreich035053',
#  'greysonhoeger169450',
#  'kendallgutmann173266',
#  'leoniemueller041439',
#  'zeldarolfson070074',
#  'tedhettinger163678',
#  'herminaparisian166382',
#  'tylercorwin078242',
#  'rachaelkerluke003455',
#  'stacylabadie013294',
#  'madysoncartwright168305',
#  'maeganschneider160008',
#  'jeremybalistreri059459',
#  'remingtonlittel024350',
#  'adrianlynch004292',
#  'ignacionikolaus040757',
#  'rosinapredovic142457',
#  'elisareichert084114',
#  'mckaylazieme170318',
#  'natashawintheiser022781',
#  'louisalesch059659',
#  'willardrenner079100',
#  'phoebemraz126636',
#  'vickygreenfelder021603',
#  'jadeblanda060023',
#  'domenickohler010418',
#  'julienstamm083000',
#  'jasonbeahan109739',
#  'terrellstamm088024',
#  'gilbertgraham090461',
#  'feliciaferry033455',
#  'lavinajerde170881',
#  'christianabeier006774',
#  'clementinemohr057024',
#  'carmelleffler018207',
#  'jaedenbatz174119',
#  'zachariahwintheiser019451',
#  'bernieblick002661',
#  'collinchristiansen023843',
#  'raheemdickens049389',
#  'nedcronin015452',
#  'norenecassin152085',
#  'antonehowe098905',
#  'geovannihand027003',
#  'lennabernier065765',
#  'abigalebarton109392',
#  'austinwalker087847',
#  'meagankshlerin132041',
#  'maxwelltremblay054007',
#  'arjunanderson092587',
#  'estefaniavonrueden104792',
#  'christokon019998',
#  'rhiannonlittel077875',
#  'romainegleason051471',
#  'jevoncremin001162',
#  'marshallsipes152929',
#  'jarvisbergnaum115684',
#  'marcellusankunding166004',
#  'taliayundt022052',
#  'ryleighmarquardt135832',
#  'abnerwilliamson027511',
#  'gardnerschmidt103389',
#  'madonnaweber029487',
#  'candidaluettgen134861',
#  'katherineolson075341',
#  'raymundoleannon008133',
#  'antonepfeffer170625',
#  'merrittlehner108301',
#  'kylermayert174638',
#  'kayaglover167210',
#  'daisyauer153635',
#  'jessegerhold049569',
#  'othopagac037371',
#  'emilianocasper074838',
#  'haskellbatz142713',
#  'lesleywaelchi003749',
#  'amelialubowitz174499',
#  'ronritchie139589',
#  'wellingtonking152765',
#  'luraarmstrong097180',
#  'caleschumm109014',
#  'donaldconsidine117149',
#  'gabriellahaag158082',
#  'jameladams054219',
#  'millielueilwitz139936',
#  'fabianwalsh160962',
#  'allenemaggio127525',
#  'gregjohnston011151',
#  'doriandurgan161463',
#  'devantemedhurst031502',
#  'damonwalsh023710',
#  'monroetorp040031',
#  'brisagutmann122967',
#  'beryltillman118561',
#  'tryciareilly047641',
#  'susancole025530',
#  'hadleymuller035367',
#  'moiseshand051902',
#  'herminiodaugherty016990',
#  'brandtarmstrong072402',
#  'noemikreiger087457',
#  'orvillelittel016126',
#  'trevaleffler032189',
#  'johannastoltenberg104756',
#  'aileenmacejkovic156783',
#  'agustinajacobs070196',
#  'lexiehessel149791',
#  'grahamschinner129543',
#  'bradenhowell095080',
#  'macydickens104677',
#  'jarodfritsch016237',
#  'simmurphy102120',
#  'bennettbeer030546',
#  'vincenzamoore084069',
#  'mittiehickle035241',
#  'flossiefunk034768',
#  'americalittle060953',
#  'rossierau147768',
#  'crawfordmorar116565',
#  'dameonkonopelski054613',
#  'kiarravon076563',
#  'bonniereinger013587',
#  'eladioconnelly144374',
#  'mosehills119483',
#  'brianapfannerstill055973',
#  'keltonhomenick012432',
#  'laylagleichner168426',
#  'jevonstiedemann150249',
#  'deshauncasper041866',
#  'jaquanhagenes153863',
#  'mitchelcorkery172067',
#  'tonihermann000702',
#  'bettyekeebler074166',
#  'shanonhomenick151060',
#  'derekstreich114859',
#  'kennedyruecker053761',
#  'shayneharris128577',
#  'albadicki072726',
#  'alessandraborer035378',
#  'darryllockman104745',
#  'raleighokon067371',
#  'janniestamm102933',
#  'hayliecummerata117977',
#  'herthabeatty121323',
#  'tesswaters008894',
#  'lauriebergstrom023912',
#  'brennanmccullough094787',
#  'stuartbeahan010570',
#  'rachellegerlach154477',
#  'destineelarkin170873',
#  'jamiebauch144823',
#  'emeliahintz091536',
#  'rosariocorwin009315',
#  'londonschmeler159561',
#  'helenaroob002539',
#  'pablohagenes050276',
#  'margarettegutmann000732',
#  'danykahilll030176',
#  'vitahettinger018100',
#  'bentonschulist076173',
#  'lottiesanford160924',
#  'kraigkohler067249',
#  'coydurgan063730',
#  'veronicaking098159',
#  'oceanereilly095651',
#  'baronleuschke051097',
#  'evelyndare063506',
#  'mariamtreutel109924',
#  'verdiemertz174116',
#  'lethalubowitz021817',
#  'edythbartell172225',
#  'amirrunte119936',
#  'kadenlynch148248',
#  'cadeconroy124490',
#  'aaliyahkoss077789',
#  'toyeffertz114640',
#  'alfordgaylord098104',
#  'providencidickens006948',
#  'camillaanderson002565',
#  'benvolkman080309',
#  'saulheathcote034521',
#  'jordymuller073075',
#  'kaitlynpouros164443',
#  'cassandrebecker059687',
#  'micheledurgan078418',
#  'oceaneborer125326',
#  'emorycummings015080',
#  'laishahilll120274',
#  'dereckschimmel055359',
#  'jimmieconroy162530',
#  'laronwalker074153',
#  'laneykuphal141868',
#  'jerroldmarks112610',
#  'sydneymacejkovic007052',
#  'noelschaefer013675',
#  'brandynboyle084212',
#  'veronahand147744']

# %%
# Since we know that our partition key is /enrollmentYear, we know that any query that targets a single valid value for the 'enrollmentYear' property 
# will be a single partition query.

query = 'SELECT * FROM students s WHERE s.enrollmentYear = 2016'
query_results = query_documents(collection_link, query)
request_charge = client.last_response_headers['x-ms-request-charge']

print(f'Length of query results: {len(query_results)}')
print(f'RU: {request_charge}')
# Out:
# Length of query results: 2020
# RU: 3.77

# %%
# If we want to execute a blanket query that will fan-out to all partitions, we simply can drop our WHERE clause that filters on a single valid
# value for our partition key path.
#
# Observe the Request Charge (in RU/s) for the executed query. You will notice that the charge is relatively greater for this query.

query = 'SELECT * FROM students s'
query_results = query_documents(collection_link, query)
request_charge = client.last_response_headers['x-ms-request-charge']

print(f'Length of query results: {len(query_results)}')
print(f'RU: {request_charge}')
# Out:
# Length of query results: 12500
# RU: 3.57

# %%
# Observe the Request Charge (in RU/s) for the executed query. You will notice that the charge is greater than a single partition but far
# less than a fan-out across all partitions.

query = 'SELECT * FROM students s WHERE s.enrollmentYear IN (2015, 2016, 2017)'
query_results = query_documents(collection_link, query)
request_charge = client.last_response_headers['x-ms-request-charge']

print(f'Length of query results: {len(query_results)}')
print(f'RU: {request_charge}')
# Out:
# Length of query results: 6157
# RU: 4.41

# %%
# To get the school-issued e-mail address, we will need to concatenate the 
# '@contoso.edu' string to the end of each alias. We can perform this action
# using the CONCAT built-in function.

query = 'SELECT CONCAT(s.studentAlias, "@contoso.edu") AS email FROM students s WHERE s.enrollmentYear = 2015'
query_results = query_documents(collection_link, query)

print(f'Length of query results: {len(query_results)}')
pprint(query_results[0])
# Out:
# Length of query results: 2026
# {'email': 'monserratlangworth070527@contoso.edu'}

# %%
# In most client-side applications, you likely would only need an array of 
# strings as opposed to an array of objects. We can use the VALUE keyword
# here to flatten our result set.

query = 'SELECT VALUE CONCAT(s.studentAlias, "@contoso.edu") FROM students s WHERE s.enrollmentYear = 2015'
query_results = query_documents(collection_link, query)

print(f'Length of query results: {len(query_results)}')
pprint(query_results[0])
# Out:
# Length of query results: 2026
# 'monserratlangworth070527@contoso.edu'

# %%
# In this query, we want to determine the current status of every
# student who enrolled in 2014. Our goal here is to eventually have a
# flattened, simple-to-understand view of every student and their current
# academic status.
# 
# You will quickly notice that the value representing the name of the
# student, using the CONCAT function, has a placeholder property name
# instead of a simple string.

query = '''
SELECT 
    CONCAT(s.firstName, " ", s.lastName), 
    s.academicStatus.warning, 
    s.academicStatus.suspension, 
    s.academicStatus.expulsion,
    s.enrollmentYear,
    s.projectedGraduationYear
FROM students s
WHERE s.enrollmentYear = 2014
'''
query_results = query_documents(collection_link, query)

print(f'Length of query results: {len(query_results)}')
pprint(query_results[0])
# Out:
# Length of query results: 2067
# {'$1': 'Vincent White',
#  'enrollmentYear': 2014,
#  'expulsion': False,
#  'projectedGraduationYear': 2018,
#  'suspension': False,
#  'warning': True}

# %%
# We will update our previous query by naming our property that uses
# a built-in function.

query = '''
SELECT 
    CONCAT(s.firstName, " ", s.lastName) AS name, 
    s.academicStatus.warning, 
    s.academicStatus.suspension, 
    s.academicStatus.expulsion,
    s.enrollmentYear,
    s.projectedGraduationYear
FROM students s
WHERE s.enrollmentYear = 2014
'''
query_results = query_documents(collection_link, query)

print(f'Length of query results: {len(query_results)}')
pprint(query_results[0])
# Out:
# Length of query results: 2067
# {'enrollmentYear': 2014,
#  'expulsion': False,
#  'name': 'Vincent White',
#  'projectedGraduationYear': 2018,
#  'suspension': False,
#  'warning': True}

# %%
# Another alternative way to specify the structure of our JSON document
# is to use the curly braces from JSON. At this point, we are defining
# the structure of the JSON result directly in our query.

query = '''
SELECT {
    "name": CONCAT(s.firstName, " ", s.lastName), 
    "isWarned": s.academicStatus.warning, 
    "isSuspended": s.academicStatus.suspension, 
    "isExpelled": s.academicStatus.expulsion,
    "enrollment": {
        "start": s.enrollmentYear,
        "end": s.projectedGraduationYear
    }
 } AS studentStatus
 FROM students s
 WHERE s.enrollmentYear = 2014
'''
query_results = query_documents(collection_link, query)

print(f'Length of query results: {len(query_results)}')
pprint(query_results[0])
# Out:
# Length of query results: 2067
# {'studentStatus': {'enrollment': {'end': 2018, 'start': 2014},
#                    'isExpelled': False,
#                    'isSuspended': False,
#                    'isWarned': True,
#                    'name': 'Vincent White'}}

# %%
# If we want to “unwrap” our JSON data and flatten to a simple array of
# like-structured objects, we need to use the 'VALUE' keyword.

query = '''
SELECT VALUE {
    "name": CONCAT(s.firstName, " ", s.lastName), 
    "isWarned": s.academicStatus.warning, 
    "isSuspended": s.academicStatus.suspension, 
    "isExpelled": s.academicStatus.expulsion,
    "enrollment": {
        "start": s.enrollmentYear,
        "end": s.projectedGraduationYear
    }
 }
 FROM students s
 WHERE s.enrollmentYear = 2014
'''
query_results = query_documents(collection_link, query)

print(f'Length of query results: {len(query_results)}')
pprint(query_results[0])
# Out:
# Length of query results: 2067
# {'enrollment': {'end': 2018, 'start': 2014},
#  'isExpelled': False,
#  'isSuspended': False,
#  'isWarned': True,
#  'name': 'Vincent White'}

# %%
# Notice that this query returns more than 3 items although the option 'maxItemCount' is specified to 3. 
# This is because the return value of 'CosmosClient.QueryItems' is converted to list in the definition
# of function 'query_documents'. The resulting list contains all items returned by the query

query = '''
SELECT VALUE {
    "name": CONCAT(s.firstName, " ", s.lastName), 
    "isWarned": s.academicStatus.warning, 
    "isSuspended": s.academicStatus.suspension, 
    "isExpelled": s.academicStatus.expulsion,
    "enrollment": {
        "start": s.enrollmentYear,
        "end": s.projectedGraduationYear
    }
 }
 FROM students s
 WHERE s.enrollmentYear = 2014
'''
query_options = {
    "enableCrossPartitionQuery": True,
    'maxItemCount': 3
}
query_iterable = query_documents(collection_link, query, query_options)

print(f'Length of query results: {len(query_iterable)}')
pprint(query_iterable)
# Out:
# Length of query results: 2067
# [{'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': True,
#   'name': 'Vincent White'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Dayana Greenfelder'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': True,
#   'name': 'Camille Schulist'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Jessica Turcotte'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Stan Leannon'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': True,
#   'name': 'Bertha Douglas'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Jack Herzog'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': True,
#   'name': 'Larue Moore'},
#  {'enrollment': {'end': 2025, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Neva Glover'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Audra Kuphal'},
#  {'enrollment': {'end': 2025, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Gus Williamson'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Terry Vandervort'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Lucinda Dooley'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Janie Mann'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Grover Carter'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Pauline Boyer'},
#  {'enrollment': {'end': 2025, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Colin Collier'},
#  {'enrollment': {'end': 2025, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Stevie Mohr'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Aric Klein'},
#  {'enrollment': {'end': 2025, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': True,
#   'name': 'Ciara Wilderman'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Edmond Abbott'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Micah Torp'},
#  {'enrollment': {'end': 2025, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Sigmund Morar'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Theodore Hintz'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Moshe Stoltenberg'},
#  {'enrollment': {'end': 2025, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Abbie Haley'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Lempi Schuster'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Deangelo Goodwin'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Herman Yundt'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Dominique Marquardt'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Baby Bogan'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Modesta Stroman'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Caesar Heller'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Guillermo Deckow'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Lowell Keeling'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Immanuel Kreiger'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Chelsea Ortiz'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Florida Mertz'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Cletus Schinner'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Watson Cremin'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Dan Nader'},
#  {'enrollment': {'end': 2025, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Buddy Erdman'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Neoma Huel'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': True,
#   'name': 'Dariana Dickens'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Dennis Hermann'},
#  {'enrollment': {'end': 2025, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Kamille Macejkovic'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Alexandria Dibbert'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Shaun Stiedemann'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': True,
#   'name': 'Holden Heller'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Guadalupe Waters'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Brigitte Wisoky'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Conrad Considine'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Mercedes Lang'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Ross Dicki'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Jaclyn Ziemann'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Jacques McKenzie'},
#  {'enrollment': {'end': 2025, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Mercedes Farrell'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Gerald Predovic'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Yvette Bashirian'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': True,
#   'name': 'Skyla Willms'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Athena Rohan'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Lamont Deckow'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Brandon Abernathy'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Bette Mitchell'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Liliana Lubowitz'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Loyce Carroll'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Marie Bartell'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Quincy Bruen'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Hanna Wuckert'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': True,
#   'name': 'Charlotte Considine'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Opal Cremin'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Ashly Gorczany'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Jessica Stark'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Kameron Koepp'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Chaz Schroeder'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': True,
#   'name': 'Iliana Kub'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': True,
#   'name': 'Okey Fadel'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Eva Pouros'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Jessy Cassin'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Abdul Buckridge'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Emilia Nikolaus'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Omari Kulas'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Karley Little'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': True,
#   'name': 'Tierra Gleichner'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Christelle Kessler'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Zena Emard'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Joelle Stehr'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Lesley Wiegand'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Donna Kuhic'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Myrtice Schuster'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Donnell Konopelski'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Francis Hane'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': True,
#   'name': 'Aileen Keeling'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Judd Carter'},
#  {'enrollment': {'end': 2025, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Santa Kunde'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Durward Hane'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Nico Mann'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Jaron Bergnaum'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Remington Roberts'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Kenna Gulgowski'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Ivy Johnson'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Modesto Fritsch'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Lourdes Mayert'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Aidan Leffler'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Jairo Hirthe'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Cydney Stehr'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Ahmed Abernathy'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Emery Langosh'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Tavares Hoeger'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Ashton Batz'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Jamaal Swaniawski'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Alyce Flatley'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'August Krajcik'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Kirk Kreiger'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Woodrow Cruickshank'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Claire Klein'},
#  {'enrollment': {'end': 2025, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Milan Mohr'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Fermin Borer'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Mara Volkman'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Nettie Trantow'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Nathen Koepp'},
#  {'enrollment': {'end': 2025, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Amaya Thompson'},
#  {'enrollment': {'end': 2025, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Bailey Green'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Arnulfo Watsica'},
#  {'enrollment': {'end': 2025, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Hallie Lockman'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Wilmer Borer'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': True,
#   'name': 'Demond Ullrich'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Marcella Ferry'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Daisha Carroll'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Christy Orn'},
#  {'enrollment': {'end': 2025, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': True,
#   'name': 'Madelyn Fay'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Reilly Gusikowski'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Stanley Jacobson'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Modesta Hahn'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Elda Romaguera'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Vivian Nicolas'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Aiyana Huels'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Jimmy Dickinson'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Bobby Romaguera'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': True,
#   'name': 'Trenton Kihn'},
#  {'enrollment': {'end': 2025, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Marshall Bashirian'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Renee Legros'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Nolan Nienow'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Brandi Ankunding'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Emmalee Okuneva'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Shaylee Oberbrunner'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Jenifer Schaefer'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': True,
#   'name': "Gail O'Kon"},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Rebekah Wolf'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': True,
#   'name': 'Velva Erdman'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Kenny Zboncak'},
#  {'enrollment': {'end': 2025, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Lavern Emard'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Hank Cartwright'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Jimmy Weber'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Stefanie Rosenbaum'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Zetta Marks'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Dudley Quitzon'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Casimir Johnston'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Ayla Bernier'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': True,
#   'name': 'Ebba Becker'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Margret Wunsch'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Will Pfannerstill'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Aiyana Leannon'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': True,
#   'name': 'Jess Pfannerstill'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Fannie Kilback'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Jenifer Mann'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Khalil Kassulke'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Valentina Boehm'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Uriah Wolf'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Dorcas Smith'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Bonita Prohaska'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Rocio White'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Linnie Bailey'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Mauricio McClure'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Ariel Wilderman'},
#  {'enrollment': {'end': 2025, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Santina Murray'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Bradly Waters'},
#  {'enrollment': {'end': 2025, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': True,
#   'name': 'Florine Haley'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Hollie Barrows'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Zelda Boyer'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Bonnie Reichert'},
#  {'enrollment': {'end': 2025, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Lindsay Collins'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Jasper Ritchie'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Jannie Kuvalis'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Eriberto Stiedemann'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Keagan Kshlerin'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Onie Oberbrunner'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Sadye Beer'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Constantin Ziemann'},
#  {'enrollment': {'end': 2025, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Loy Terry'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Dewayne Klocko'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Issac Jacobson'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Rhea Legros'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Emie Braun'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': True,
#   'name': 'Missouri Hartmann'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Diamond Fadel'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Helene Mills'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Grover Satterfield'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Lorena Huels'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Dayna Dietrich'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Madisen Hegmann'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Bert Dibbert'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': True,
#   'name': 'Andres Schumm'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Elenora Leffler'},
#  {'enrollment': {'end': 2025, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': True,
#   'name': 'Sharon Shanahan'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Neil Spinka'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Harry Maggio'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Myron Emard'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Ericka Goldner'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Mitchel Schultz'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Salma Balistreri'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Beatrice Gleichner'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': True,
#   'name': "Albert O'Hara"},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Candice Marks'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Johnnie Mann'},
#  {'enrollment': {'end': 2025, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Solon Lowe'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': True,
#   'name': 'Rusty Prosacco'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Roberta Hackett'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': True,
#   'name': 'Heath Trantow'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Shyann Shanahan'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Waino McClure'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Alicia Schowalter'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Rosemary Goyette'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Idella Zieme'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': True,
#   'name': 'Elody Bashirian'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Everette Boyle'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Cristopher Doyle'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': True,
#   'name': 'Neil Lind'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Gudrun Jones'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Novella Hettinger'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Josie Paucek'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Cassandre King'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Lane Hyatt'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Selina Jacobs'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Howard Considine'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Chance Crona'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Magdalen Roberts'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Bettye Hodkiewicz'},
#  {'enrollment': {'end': 2025, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Akeem Paucek'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Kale Schamberger'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Kitty Becker'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Newell Konopelski'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Devyn Farrell'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Serena Wunsch'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': True,
#   'name': 'Delta Doyle'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Houston Kihn'},
#  {'enrollment': {'end': 2025, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Margarete Gleichner'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Jadyn Trantow'},
#  {'enrollment': {'end': 2025, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Carolina Feest'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Merlin Lakin'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Pearline Thompson'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Alysha Erdman'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Ryan Veum'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Ottilie Walsh'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Athena Weissnat'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Ottilie Fahey'},
#  {'enrollment': {'end': 2025, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Junius Ziemann'},
#  {'enrollment': {'end': 2025, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': True,
#   'name': 'Luigi Olson'},
#  {'enrollment': {'end': 2025, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Otto DuBuque'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Cecil Greenholt'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Furman Hansen'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Ignacio Ondricka'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Yasmin Conn'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Kaley Kuphal'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Richmond Mayer'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Harvey Wiza'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Diamond Gleichner'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Antonetta Watsica'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Werner Hermiston'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Janick Schiller'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Adell Bayer'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Zakary Kemmer'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Adrienne Davis'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Elta Bartell'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Briana Reynolds'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Edythe Kohler'},
#  {'enrollment': {'end': 2025, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': True,
#   'name': 'Casandra Wintheiser'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': "Caitlyn O'Conner"},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Anthony Rice'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Kaley Gulgowski'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Carlos Lesch'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Oran Oberbrunner'},
#  {'enrollment': {'end': 2025, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Titus Lindgren'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Glenda Schaefer'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Theodore Graham'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Damon Hills'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': True,
#   'name': 'Annette Bosco'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Robb Schuppe'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Shanel Keebler'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Doris Corwin'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Lelah Ryan'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Lucas Gusikowski'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Laura Maggio'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Antone Macejkovic'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Justina Doyle'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Hollis Orn'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Madison Little'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Jaleel Ferry'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Carley Flatley'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Christelle Rolfson'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Hellen Kautzer'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Hannah Bogan'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Pearline Batz'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Rosendo Friesen'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Elva Johns'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Art Lind'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Rebecca Keebler'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Leone Douglas'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Chelsea Christiansen'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Albertha Wehner'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': True,
#   'name': 'Gladyce Stiedemann'},
#  {'enrollment': {'end': 2025, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Herbert Muller'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Kenneth Jakubowski'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': True,
#   'name': 'Wendy Gibson'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': True,
#   'name': 'Colby Casper'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Randy Senger'},
#  {'enrollment': {'end': 2025, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Kelly Dibbert'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Laverne Wilderman'},
#  {'enrollment': {'end': 2025, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': True,
#   'name': 'Hollis Kuvalis'},
#  {'enrollment': {'end': 2025, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Danial Greenfelder'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Talia Hirthe'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Aurore Zemlak'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Heber Walter'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Salvador Connelly'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Bradley Cormier'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Mack Cummings'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Tobin Daniel'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Zachery Senger'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Osbaldo West'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Alysha Stark'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': "Cristian O'Kon"},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Kariane Kshlerin'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Earlene Prosacco'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Brando King'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Demetris Johns'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Albina Baumbach'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
# ...
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Ena Bernhard'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Hudson Kemmer'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Arlo Gaylord'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Ursula Stehr'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Hoyt Treutel'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Marie Leannon'},
#  {'enrollment': {'end': 2025, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Clinton Davis'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Ardella Dickinson'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Jaeden Corwin'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Van Kautzer'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Percy Kub'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Carlotta Champlin'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Brandon Marvin'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Elda Ward'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Quinton Brekke'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': True,
#   'name': 'Ephraim Schuppe'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Raphael Haley'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Therese Senger'},
#  {'enrollment': {'end': 2025, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Maybell Baumbach'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Grady Skiles'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Verlie Nader'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Antonette Kuhlman'},
#  {'enrollment': {'end': 2025, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Devan Hamill'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Anissa Deckow'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Antwon Yost'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Minnie Roob'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Adeline Gerlach'},
#  {'enrollment': {'end': 2025, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Gail McDermott'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': True,
#   'name': 'Gloria Roob'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Marquise Feil'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Alvera Wolf'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Dan Krajcik'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Shayne Berge'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Angus Willms'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Milton Cruickshank'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Alexis Johnson'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Rebekah Hackett'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Easter Huel'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Dell Spencer'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': True,
#   'name': 'Haven Lehner'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Tom Langworth'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Donny Ankunding'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Greyson Ernser'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Cordell Gutmann'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Dianna Crona'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Jaylon Kautzer'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Belle Collier'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Gunnar Konopelski'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Aniyah Schinner'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Betty Erdman'},
#  {'enrollment': {'end': 2025, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Pansy Brown'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Sid Ullrich'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Everardo Collins'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Roslyn Olson'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Brooklyn Ledner'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Alanis Keebler'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Jade Mohr'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Arvel Ernser'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Elta Ryan'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Mabel Marvin'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Collin Hettinger'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Violet Simonis'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Johanna Bernier'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Daphne Fisher'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Bret Hayes'},
#  {'enrollment': {'end': 2025, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': True,
#   'name': 'Lulu Crist'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'River Abbott'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Jamie Strosin'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Mckenzie Corwin'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Cassie Dare'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Riley Morar'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Monroe Kuphal'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Domingo Lockman'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Marley Altenwerth'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Madyson Moen'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Marian Walsh'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Kristina Thiel'},
#  {'enrollment': {'end': 2025, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Tony Effertz'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Joel Barrows'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Candice Blanda'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Bradford Stiedemann'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Cristal Bergstrom'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Hellen Roob'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': True,
#   'name': 'Alisa Kutch'},
#  {'enrollment': {'end': 2025, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Dorian Auer'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Jacques Spinka'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Lera Sawayn'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Corbin Kub'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Fae Kemmer'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Mervin Hirthe'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Madisen Hackett'},
#  {'enrollment': {'end': 2025, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Ola Kuhn'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Aaron Cole'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Madalyn Kirlin'},
#  {'enrollment': {'end': 2022, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Lemuel Leffler'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Marvin Koepp'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Chris Buckridge'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Demetris Kuvalis'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Ward Gislason'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Freddy Kozey'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Stan Gleichner'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Rahsaan Parisian'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Olin Huel'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Sarina Heller'},
#  {'enrollment': {'end': 2025, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Floy Flatley'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Daija Klein'},
#  {'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Manuel Stanton'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Gayle Swaniawski'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Halle Pacocha'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Keyon Stoltenberg'},
#  {'enrollment': {'end': 2023, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Harrison Ankunding'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Yasmeen Morissette'},
#  {'enrollment': {'end': 2021, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Antone Wiza'}]

# %%
# To leverage the pagination capability from Azure Cosmos DB, the returned value from 'CosmosClient.QueryItems'
# should not be converted to 'list' type. The 'fetch_next_block' function is used to obtain the next page from
# the 'QueryIterable' object

query = '''
SELECT VALUE {
    "name": CONCAT(s.firstName, " ", s.lastName), 
    "isWarned": s.academicStatus.warning, 
    "isSuspended": s.academicStatus.suspension, 
    "isExpelled": s.academicStatus.expulsion,
    "enrollment": {
        "start": s.enrollmentYear,
        "end": s.projectedGraduationYear
    }
 }
 FROM students s
 WHERE s.enrollmentYear = 2014
'''
query_options = {
    "enableCrossPartitionQuery": True,
    'maxItemCount': 3
}
query_iterable = client.QueryItems(collection_link, query, query_options)

query_page = query_iterable.fetch_next_block()

print(f'Length of query results: {len(query_page)}')
pprint(query_page)
# Out:
# Length of query results: 3
# [{'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': True,
#   'name': 'Vincent White'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Dayana Greenfelder'},
#  {'enrollment': {'end': 2024, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': True,
#   'name': 'Camille Schulist'}]

# %%
# Calling 'fetch_next_block' again returns the next 3 items in the array.

query_page = query_iterable.fetch_next_block()

print(f'Length of query results: {len(query_page)}')
pprint(query_page)
# Out:
# Length of query results: 3
# [{'enrollment': {'end': 2020, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Jessica Turcotte'},
#  {'enrollment': {'end': 2019, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': False,
#   'name': 'Stan Leannon'},
#  {'enrollment': {'end': 2018, 'start': 2014},
#   'isExpelled': False,
#   'isSuspended': False,
#   'isWarned': True,
#   'name': 'Bertha Douglas'}]

# %%
def delete_database(id):
    print('Delete Database')

    try:
       database_link = 'dbs/' + id
       client.DeleteDatabase(database_link)

       print(f'Database with id "{id}" was deleted')

    except errors.HTTPFailure as e:
        if e.status_code == 404:
           print('A database with id "{id}" does not exist')
        else: 
            raise

# %%
# Clean up
delete_database(COSMOSDB_DB_ID)
# Out:
# Delete Database
# Database with id "UniversityDatabase" was deleted
